# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from imageio import imread

img = imread('./images/mars.jpeg')
img_tinted = np.uint8(img * [0.5, 0.9, 0.8])

plt.subplot(1, 2, 1)
plt.imshow(img)

plt.subplot(1, 2, 2)
plt.imshow(img_tinted)

plt.show()
